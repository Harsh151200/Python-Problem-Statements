# %%
from nsepy import *
from datetime import *

data = get_history(symbol = 'INFY', 
                   start =  (date.today() - timedelta(days = 360)), end = date.today())
data[['Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
infy = get_history(symbol = 'INFY', 
                    start =  (date.today() - timedelta(days = 360)), end = date.today())
infy
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2020-02-14   INFY     EQ      792.25   794.50   799.20   784.60   786.30
# 2020-02-17   INFY     EQ      786.45   790.30   793.45   783.30   788.85
# 2020-02-18   INFY     EQ      789.45   785.00   799.05   783.65   798.50
# 2020-02-19   INFY     EQ      797.65   800.00   804.85   796.15   800.40
# 2020-02-20   INFY     EQ      800.45   803.25   806.10   793.85   796.80
# ...           ...    ...         ...      ...      ...      ...      ...
# 2021-02-02   INFY     EQ     1260.90  1280.00  1294.40  1263.60  1275.50
# 2021-02-03   INFY     EQ     1271.25  1277.65  1304.00  1273.00  1285.00
# 2021-02-04   INFY     EQ     1284.65  1285.00  1293.40  1272.05  1278.50
# 2021-02-05   INFY     EQ     1279.35  1286.40  1288.75  1262.00  1273.00
# 2021-02-08   INFY     EQ     1272.10  1285.50  1310.00  1275.50  1310.00
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# ...

# %%
infy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 2020-02-14 to 2021-02-08
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              245 non-null    object
#  1   Series              245 non-null    object
#  2   Prev Close          245 non-null    float64
#  3   Open                245 non-null    float64
#  4   High                245 non-null    float64
#  5   Low                 245 non-null    float64
#  6   Last                245 non-null    float64
#  7   Close               245 non-null    float64
#  8   VWAP                245 non-null    float64
#  9   Volume              245 non-null    int64
#  10  Turnover            245 non-null    float64
#  11  Trades              245 non-null    int64
#  12  Deliverable Volume  245 non-null    int64
#  13  %Deliverble         245 non-null    float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 28.7+ KB

# %%
infy.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count   245.000000   245.000000   245.000000   245.000000   245.000000
# mean    928.686735   930.035918   943.924490   918.151224   931.284490
# std     226.986871   228.874682   228.204373   227.074454   228.307407
# min     526.450000   509.250000   558.000000   509.250000   529.150000
# 25%     705.550000   707.000000   711.900000   698.100000   706.400000
# 50%     947.050000   947.500000   955.500000   938.400000   948.550000
# 75%    1122.500000  1123.000000  1139.000000  1110.000000  1123.500000
# max    1387.150000  1378.000000  1392.800000  1360.000000  1388.650000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count   245.000000   245.000000  2.450000e+02  2.450000e+02     245.000000
# mean    930.773673   931.146408  1.112574e+07  1.024831e+15  203774.706122
# std     228.075179   227.254724  7.390729e+06  7.334550e+14   96950.794512
# ...

# %%
# Stock futures (Similarly for index futures, set index = True)
expiry_date_get = get_expiry_date(year=date.today().year, month=date.today().month, index=True, stock=False)

stock_fut = get_history(symbol="INFY",
                            start=date(2020,2,8),
                            end=date(2020,3,8),
                            futures=True,
                            expiry_date=date(2020,3,28),
                            index= True)
stock_fut
# Out:
# Empty DataFrame
# Columns: [Symbol, Expiry, Open, High, Low, Close, Last, Settle Price, Number of Contracts, Turnover, Open Interest, Change in OI, Underlying]
# Index: []
